# %% [markdown]
# ## For checking  spotify go to spotipyloop.ipynb

# %%
import json
import requests as req
import pandas as pd
import os
import logging
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth

# %%
from webdriver_manager.chrome import ChromeDriverManager
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd
import selenium
import json 
from selenium import webdriver
import os
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
import sys

# %%
with open('secret2.txt') as f:
    secret2 = f.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-429fe41eb987> in <module>
# ----> 1 with open('secret2.txt') as f:
#       2     secret2 = f.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'secret2.txt'

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="d663de0869444f16aa6d03d9c8ae4fe3",
                                                           client_secret=secret2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3174ad8a6666> in <module>
#       1 sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="d663de0869444f16aa6d03d9c8ae4fe3",
# ----> 2                                                            client_secret=secret2))
#       3
#
# NameError: name 'secret2' is not defined

# %%
artists_spoti = pd.read_csv(r'/mnt/c/Users/Palmira/Desktop/Ironhack/Semana4/project_ETL/src/Output_data/artits_streamed_spoti.csv',encoding = "ISO-8859-1")

# %%
artists_spoti
# Out:
#      streaming_rank              artist  lead_streams  featured_streams  \
# 0                 1               Drake   44536306403       17365495866
# 1                 2          Ed Sheeran   33626490825        2470098686
# 2                 3           Bad Bunny   31591913975        4259239853
# 3                 4       Ariana Grande   29293717743        1853878508
# 4                 5          The Weeknd   29162520751        3653938791
# ..              ...                 ...           ...               ...
# 995             996  Dave Matthews Band    1191228948          12494077
# 996             997             MF DOOM    1190155840          84749542
# 997             998           Jake Owen    1189060122          30523629
# 998             999            No Doubt    1187404815            276817
# 999            1000        Wu-Tang Clan    1187400020          11075579
#
#      Tracks  1b+  100m+  10m+  1m+ last_update
# 0       250    5    116   242  245    02/04/22
# ...

# %%
art1 = artists_spoti['artist'][0]

# %%
spoti_info = sp.search(q=art1,limit=10, type='artist')

# %%
df = pd.DataFrame(spoti_info)

# %%
df.explode('artists').reset_index(drop=False)
# Out:
#        index                                            artists
# 0       href  https://api.spotify.com/v1/search?query=Drake&...
# 1      items  {'external_urls': {'spotify': 'https://open.sp...
# 2      items  {'external_urls': {'spotify': 'https://open.sp...
# 3      items  {'external_urls': {'spotify': 'https://open.sp...
# 4      items  {'external_urls': {'spotify': 'https://open.sp...
# 5      items  {'external_urls': {'spotify': 'https://open.sp...
# 6      items  {'external_urls': {'spotify': 'https://open.sp...
# 7      items  {'external_urls': {'spotify': 'https://open.sp...
# 8      items  {'external_urls': {'spotify': 'https://open.sp...
# 9      items  {'external_urls': {'spotify': 'https://open.sp...
# 10     items  {'external_urls': {'spotify': 'https://open.sp...
# 11     limit                                                 10
# 12      next  https://api.spotify.com/v1/search?query=Drake&...
# 13    offset                                                  0
# ...

# %%
df= pd.json_normalize(df.iloc[1].artists)

# %%
df.drop(axis=0, index=None, columns = ["href", "images", "external_urls.spotify"], inplace=True)

# %%
artist = df[:1]
artist
# Out:
#                                               genres                      id  \
# 0  [canadian hip hop, canadian pop, hip hop, rap,...  3TVXtAsR1Inumwj472S9r4
#
#     name  popularity    type                                    uri  \
# 0  Drake          98  artist  spotify:artist:3TVXtAsR1Inumwj472S9r4
#
#   followers.href  followers.total
# 0           None         60756197

# %%
artist.rename(columns={"id":"artist_id"},inplace=True)
# Out:
# /home/lapalmi87/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
artist
# Out:
#                                               genres               artist_id  \
# 0  [canadian hip hop, canadian pop, hip hop, rap,...  3TVXtAsR1Inumwj472S9r4
#
#     name  popularity    type                                    uri  \
# 0  Drake          98  artist  spotify:artist:3TVXtAsR1Inumwj472S9r4
#
#   followers.href  followers.total
# 0           None         60756197

# %% [markdown]
# results = sp.search(q='Drake')
# results2={}
#
#
# for idx, track in enumerate(results['tracks']['items']):
#     print(idx, track['name'], track['popularity'])
#     results2={'index' : idx,'Artist': track['name'],'popularity': track['popularity']}
#
# results2
#
# case_list={}
# for idx, track in enumerate(results['tracks']['items']):
#     case ={'index' : idx,'Artist': track['name'],'popularity': track['popularity']}
# case
#
# adele = sp.search(q='Drake',limit=10, type='artist')
# adele2= pd.json_normalize(adele)
# #adele2.explode("artists.items")
# adele2

# %% [markdown]
# artist_uri = artist['uri']
#
# album = sp.artist_albums(artist_uri,limit=10, album_type='album')
# df_alb = pd.DataFrame(album)
# df_alb
# df_alb= pd.json_normalize(df.iloc[1])
# #df.explode('album').reset_index(drop=False)
# #df.explode('artists').reset_index(drop=False)

# %%
artist_id='7MPGCB854Qo4alYMOPkBka'

artist = sp.artist('https://api.spotify.com/v1/artists/'+artist_id)
print(artist)
# Out:
# Expected id of type artist but found type artists https://api.spotify.com/v1/artists/7MPGCB854Qo4alYMOPkBka
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/7MPGCB854Qo4alYMOPkBka'}, 'followers': {'href': None, 'total': 109781}, 'genres': ['bedroom pop', 'indie pop'], 'href': 'https://api.spotify.com/v1/artists/7MPGCB854Qo4alYMOPkBka', 'id': '7MPGCB854Qo4alYMOPkBka', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab6761610000e5eb8886486feba69252eca7a09b', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/ab676161000051748886486feba69252eca7a09b', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/ab6761610000f1788886486feba69252eca7a09b', 'width': 160}], 'name': 'Ritt Momney', 'popularity': 67, 'type': 'artist', 'uri': 'spotify:artist:7MPGCB854Qo4alYMOPkBka'}

# %% [markdown]
# ## Traernos los track id´s y pasarles un bucle en el que nos diera la informacion de spotify que queremos para todos.

# %%
import pandas as pd
import mysql.connector as conn
from sqlalchemy import create_engine

# %%
db=conn.connect(host='localhost',
                     user='root',
                     passwd='admin',
                     database='Spotify')

cursor=db.cursor()

# %%
str_conn='mysql+pymysql://root:admin@localhost:3306/Spotify'

motor=create_engine(str_conn)  # motor de conexion

# %% [markdown]
# ## NO SE PUEDEN SACAR LAS REPRODUCCIONES DE CANCIONES.

# %% [markdown]
# Aquí quiero hacer una búsqueda en selenium que me de las reproducciones de las canciones

# %%
# Out:
# [{'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#     'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#     'id': '3TVXtAsR1Inumwj472S9r4',
#     'name': 'Drake',
#     'type': 'artist',
#     'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
# ...

# %%
'https://open.spotify.com/search/track:%22Something%22%20artist:%22The%20Beatles%22'

# %% [markdown]
# ### TO USE IN SECRET MODE:
# with open('secret.txt') as f:
#     secret = f.readline()
# print (secret)
#
# #sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id="d663de0869444f16aa6d03d9c8ae4fe3",client_secret="47d3341ba76c4cf9a666c575b1c77ff9"))
